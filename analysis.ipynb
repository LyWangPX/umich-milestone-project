# %% [markdown]
# # Analysis

# %% [markdown]
# _Importing Libraries:_

# %%
import pandas as pd

# %% [markdown]
# *_Reading in the data:_*
#
# Let's read in the cleaned data and take a look at the first 10 rows to get an idea of what it looks like inside.

# %%
# using pd.read_csv() to read in the cleaned data set, then showing the first 10 rows using .head() to get an idea of what's inside
df = pd.read_csv("market_data_cleaned.csv")

df.head(10)
# Out:
#          Date  SP500_Close   SP500_High    SP500_Low   SP500_Open  \
# 0  2010-01-12  1136.219971  1143.810059  1131.770020  1143.810059
# 1  2010-01-13  1145.680054  1148.400024  1133.180054  1137.310059
# 2  2010-01-14  1148.459961  1150.410034  1143.800049  1145.680054
# 3  2010-01-15  1136.030029  1147.770020  1131.390015  1147.719971
# 4  2010-01-19  1150.229980  1150.449951  1135.770020  1136.030029
# 5  2010-01-20  1138.040039  1147.949951  1129.250000  1147.949951
# 6  2010-01-21  1116.479980  1141.579956  1114.839966  1138.680054
# 7  2010-01-22  1091.760010  1115.489990  1090.180054  1115.489990
# 8  2010-01-25  1096.780029  1102.969971  1092.400024  1092.400024
# 9  2010-01-26  1092.170044  1103.689941  1089.859985  1095.800049
#
#    SP500_Volume  Nasdaq_Close  Nasdaq_High   Nasdaq_Low  Nasdaq_Open  ...  \
# 0  4.716160e+09   2282.310059  2298.850098  2272.699951  2297.280029  ...
# 1  4.170360e+09   2307.899902  2313.030029  2274.120117  2289.459961  ...
# ...
